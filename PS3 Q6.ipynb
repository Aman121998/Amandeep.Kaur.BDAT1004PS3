# %%
#!/usr/bin/env python
# coding: utf-8

#                                  Question 6

# In[15]:


import pandas as pd 
data = pd.read_csv("C:\\Users\\DELL\\Downloads\\us-marriages-divorces-1867-2014.csv")
print(data[['Marriages_per_1000']])
data['Divorces_per_1000']


# In[17]:


import pandas as pd
from matplotlib import pyplot as plt

# Set the figure size
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

# Make a list of columns
columns = [ 'Marriages_per_1000', 'Divorces_per_1000']

# Read a CSV file
df = pd.read_csv("C:\\Users\\DELL\\Downloads\\us-marriages-divorces-1867-2014.csv", usecols=columns)

# Plot the lines
df.plot()

plt.show()


# In[ ]:
# Out:
#      Marriages_per_1000
# 0                   9.7
# 1                   9.1
# 2                   9.0
# 3                   8.8
# 4                   8.8
# ..                  ...
# 140                 7.3
# 141                 7.1
# 142                 6.8
# 143                 6.8
# 144                 6.8
#
# [145 rows x 1 columns]

# %%
#!/usr/bin/env python
# coding: utf-8

#                                                     Question 10

# In[2]:


import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("C:\\Users\\DELL\\Downloads\\arcade-revenue-vs-cs-doctorates.csv")
df.plot()  # plots all columns against index
df.plot(kind='scatter',x='Total Arcade Revenue (billions)',y='Computer Science Doctorates Awarded (US)') # scatter plot
df.plot(kind='density')  # estimate density function
# df.plot(kind='hist')  # histogram


# In[ ]:
# Out:
# <AxesSubplot:ylabel='Density'>

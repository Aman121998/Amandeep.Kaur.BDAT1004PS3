# %%
#!/usr/bin/env python
# coding: utf-8

#                                                             Question 2

# In[36]:


import pandas as pd
euro12 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")
print(euro12[['Goals']])


# Ques 5. How many team participated in the Euro2012?
# Ans: 16
# Ques 6. What is the number of columns in the dataset?
# Ans: 3 colums are present in the dataset

# In[37]:


data = euro12[['Team','Yellow Cards','Red Cards']]
discipline = pd.DataFrame(data)
print(discipline)


# In[9]:


discipline.sort_values(["Red Cards"], axis=0,ascending=[False], inplace=True)
print(discipline)


# In[10]:


discipline.sort_values(["Yellow Cards"], axis=0,ascending=[False], inplace=True)
print(discipline)


# In[13]:


discipline['Yellow Cards'].mean()


# In[24]:


euro12.query('Goals >= 6')


# In[26]:


euro12['Team'].str.startswith('G')


# In[28]:


euro12.iloc[: , :7]


# In[29]:


euro12.iloc[: , :-3]


# In[35]:



print(euro12.loc[[3,7,12], ['Team','Shooting Accuracy']])


# In[ ]:
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# ...

# %%
#!/usr/bin/env python
# coding: utf-8

#                                                        Question 4

# In[11]:


import pandas as pd
import numpy as np
data = pd.read_fwf("C:\\Users\\DELL\\Downloads\\roman-emperor-reigns.csv")

data['Date'] = data[data.columns[0 :3]].apply(
    lambda x: '-'.join(x.dropna().astype(str)), axis=1)
print(data)

# mutate(across(cols = starts_with("targ2"), 
#                 ~replace(., cumall(. != 0), NA)))


# In[12]:


data.drop(columns=["Yr", "Mo","Dy"])
#Move last Column to First Column
new_cols = ['Date','RPT',
 'VAL',
 'ROS',
 'KIL',
 'SHA',
 'BIR',
 'DUB',
 'CLA',
 'MUL',
 'CLO',
 'BEL',
 'MAL',]
data=data[new_cols]
#or
data=data.reindex(columns=new_cols)
print(data)


# In[13]:


cols = data.columns[:1]
data[cols] = data[cols].apply(pd.to_datetime, errors='coerce')
print(data)


# Year 2061? Do we really have data from this year?
# Ans: Yes we have data from this year 

# In[14]:


data.info()


# In[15]:


bool_series = pd.notnull(data[['RPT','VAL','ROS', 'KIL','SHA' , 'BIR' , 'DUB', 'CLA','MUL','CLO','BEL','MAL']]).sum()
print(bool_series)


# In[16]:


data.notnull().sum()


# In[17]:


mean_val =  data.loc[:, data.columns != 'Date'].mean()
mean_val.mean()


# In[18]:


data_val = data[['RPT','VAL','ROS', 'KIL','SHA' , 'BIR' , 'DUB', 'CLA','MUL','CLO','BEL','MAL']]
loc_stats= pd.DataFrame(data_val)
print(loc_stats)


# In[19]:


loc_stats.min()


# In[20]:


loc_stats.max()


# In[21]:


loc_stats.mean()


# In[22]:


day_val = data[['Date','RPT','VAL','ROS', 'KIL','SHA' , 'BIR' , 'DUB', 'CLA','MUL','CLO','BEL','MAL']]
loc_stats =pd.DataFrame(day_val)
print(loc_stats)


# In[23]:


mean_val = loc_stats.loc[:, loc_stats.columns != 'Date'].mean()
print(mean_val)


# In[28]:


min_val = loc_stats.loc[:, loc_stats.columns != 'Date'].min()
print(min_val)


# In[27]:


max_val = loc_stats.loc[:, loc_stats.columns != 'Date'].max()
print(max_val)


# In[ ]:
# Out:
#      Emperor,Length_of_Reign,Cause_of_Death  \
# 0      Augustus,40.58,Possibly assassinated
# 1       Tiberius,22.5,Possibly assassinated
# 2                Caligula,4.83,Assassinated
# 3      Claudius,13.75,Possibly assassinated
# 4                        Nero,13.67,Suicide
# ..                                      ...
# 63          Valentinian I,11,Natural causes
# 64               Valens,14,Killed in battle
# 65                  Gratian,16,Assassinated
# 66  Valentinian II,17,Possibly assassinated
# 67           Theodosius I,16,Natural causes
#
#                                        Date
# 0      Augustus,40.58,Possibly assassinated
# 1       Tiberius,22.5,Possibly assassinated
# 2                Caligula,4.83,Assassinated
# 3      Claudius,13.75,Possibly assassinated
# 4                        Nero,13.67,Suicide
# ..                                      ...
# 63          Valentinian I,11,Natural causes
# 64               Valens,14,Killed in battle
# ...

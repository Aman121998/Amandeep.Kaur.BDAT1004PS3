# %%
#!/usr/bin/env python
# coding: utf-8

#                                Question 9

# In[35]:


import pandas as pd
from matplotlib.pyplot import pie, axis, show
get_ipython().run_line_magic('matplotlib', 'inline')

df = pd.read_csv ('C:\\Users\\DELL\\Downloads\\roman-emperor-reigns.csv')

sums = df.groupby(df["Emperor"])["Length_of_Reign"].sum()
axis('equal');
pie(sums, labels=sums.index);

show()


# In[ ]:





# In[ ]:
